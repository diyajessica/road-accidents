# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/road-accident-severity-in-india/Road.csv

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#DE3163;
#            font-size:200%;
#            font-family:Garamond;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           font-size:120%;
#           text-align:center;">
# ROAD ACCIDENTS IN INDIA
# </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#FF6347;
#            font-size:200%;
#            font-family:Monaco;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           font-size:120%;
#           text-align:center;">
# <h3>Workflow:</h3>
#     <ol>
#   <li>Importing the Necessary Libraries</li>
#   <li> Loading the file</li>
#   <li>Basic Understanding of Data:</li>
#     <ul>
#         <li>Checking shape</li>
#         <li> Preview of datset</li>
#         <li> Column description </li>
#         <li>Basic info of datset </li>
#         <li> Fetching Column names</li>
#         <li> Checking data type of columns</li>
#         </ul>
#   <li>Preprocessing</li>
# </ol>
#
# </div>
# </p>
# </div>

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#FF7F50;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
#     Importing the required libraries:
#     <ul>
#         <li> Importing Numpy for Mathematical Operations on Arrays and Dataframe.</li>
#         <li> Importing Pandas for Reading Data and Data Manipulation.</li>
#          <li> Importing Matplotlib & Seaborn to show insights and visualisation from the dataset.</li>
#           <li> Importing Warnings for Warnings Messages that are typically issued in dataframe where it is used to show warning messages.</li>
#
# </p>
# </div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#FAFAD2;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
#     Loading The Dataset
#     </p>
#     </div>

# %%
df=pd.read_csv("/kaggle/input/road-accident-severity-in-india/Road.csv")
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#FAFAD2;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
#    Preview of The Dataset
#     </p>
#     </div>

# %%
df.sample(5)
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 1292  10:12:00    Saturday              31-50          Male
# 6939  16:53:00    Saturday              31-50          Male
# 1040  17:45:00      Friday              31-50          Male
# 2391  21:05:00      Sunday            Unknown        Female
# 9655  11:38:00    Saturday              31-50          Male
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 1292  Junior high school                Employee         Above 10yr
# 6939  Junior high school                Employee             5-10yr
# 1040  Junior high school                Employee         Above 10yr
# 2391                 NaN                   Owner                NaN
# 9655   Elementary school                Employee             5-10yr
#
#         Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  \
# 1292  Public (12 seats)            Owner                 5-10yrs
# ...

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#FAFAD2;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
# ​
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
#    Basic Understanding of The Dataset
#     </p>
#     </div>

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
#    How big the data is?
#     </p>
#     </div>

# %%
df.shape
# Out:
# (12316, 32)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    It has 12316 rows and 32 columns
# </p>

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
#    Fetching Column Names
#     </p>
#     </div>

# %%
df.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    It has following columns: 'Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'.`

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
#    Information:
#     </p>
#     </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#  -  It has few missing values in some columns.
#  -  time should be in date-time format and age , casualty severity should be in int. for better analysis.

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
#   Checking the Unique Values:
#     </p>
#     </div>

# %%
for i in df.columns:
    print(i,"------------------",df[i].unique())
# Out:
# Time ------------------ ['17:02:00' '1:06:00' '14:15:00' ... '7:24:00' '19:18:00' '2:47:00']
# Day_of_week ------------------ ['Monday' 'Sunday' 'Friday' 'Wednesday' 'Saturday' 'Thursday' 'Tuesday']
# Age_band_of_driver ------------------ ['18-30' '31-50' 'Under 18' 'Over 51' 'Unknown']
# Sex_of_driver ------------------ ['Male' 'Female' 'Unknown']
# Educational_level ------------------ ['Above high school' 'Junior high school' nan 'Elementary school'
#  'High school' 'Unknown' 'Illiterate' 'Writing & reading']
# Vehicle_driver_relation ------------------ ['Employee' 'Unknown' 'Owner' nan 'Other']
# Driving_experience ------------------ ['1-2yr' 'Above 10yr' '5-10yr' '2-5yr' nan 'No Licence' 'Below 1yr'
#  'unknown']
# Type_of_vehicle ------------------ ['Automobile' 'Public (> 45 seats)' 'Lorry (41?100Q)' nan
#  'Public (13?45 seats)' 'Lorry (11?40Q)' 'Long lorry' 'Public (12 seats)'
#  'Taxi' 'Pick up upto 10Q' 'Stationwagen' 'Ridden horse' 'Other' 'Bajaj'
# ...

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#  -  It has few missing values in some columns.
#  -  time should be in date-time format and age , casualty severity etc can be encoded for a better analaysis

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#FAFAD2;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
# ​
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
#    Preprocessing
#     </p>
#     </div>

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
#   Checking the Missing Values:
#     </p>
#     </div>

# %%
for i in df.columns:
    if df[i].isnull().sum()>0:
        print(i,"----------------------",df[i].isnull().sum()*100/df.shape[0])
# Out:
# Educational_level ---------------------- 6.01656381942189
# Vehicle_driver_relation ---------------------- 4.70120168886002
# Driving_experience ---------------------- 6.731081519974017
# Type_of_vehicle ---------------------- 7.713543358233193
# Owner_of_vehicle ---------------------- 3.9136083143877882
# Service_year_of_vehicle ---------------------- 31.893471906463137
# Defect_of_vehicle ---------------------- 35.94511204936668
# Area_accident_occured ---------------------- 1.9405651185449821
# Lanes_or_Medians ---------------------- 3.126014939915557
# Road_allignment ---------------------- 1.152971744072751
# Types_of_Junction ---------------------- 7.202013640792465
# Road_surface_type ---------------------- 1.3965573238064306
# Type_of_collision ---------------------- 1.2585254952906788
# Vehicle_movement ---------------------- 2.5008119519324454
# Work_of_casuality ---------------------- 25.966222799610264
# Fitness_of_casuality ---------------------- 21.39493341994154

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
#   Handling the Missing Values:
#     </p>
#     </div>

# %%
df["Educational_level"].mode()
# Out:
# 0    Junior high school
# Name: Educational_level, dtype: object

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - according to me educational level is not a important metric so we can drop that column .

# %%
df.drop(columns=["Educational_level"],inplace=True)

# %%
df["Vehicle_driver_relation"].unique()
# Out:
# array(['Employee', 'Unknown', 'Owner', nan, 'Other'], dtype=object)

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - We will fill this column by unknown or other as mode is employee but not all owners can be employees.

# %%
df["Vehicle_driver_relation"]=df["Vehicle_driver_relation"].fillna("Other")

# %%
df["Vehicle_driver_relation"].isnull().sum()
# Out:
# 0

# %%
df["Driving_experience"].mode()
# Out:
# 0    5-10yr
# Name: Driving_experience, dtype: object

# %%
df["Driving_experience"].unique()
# Out:
# array(['1-2yr', 'Above 10yr', '5-10yr', '2-5yr', nan, 'No Licence',
#        'Below 1yr', 'unknown'], dtype=object)

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - We will fill this column by unknown  as mode is 5-10 but not all nan have experience of 5-10 yrs.

# %%
df["Driving_experience"]=df["Driving_experience"].fillna("unknown")

# %%
df["Type_of_vehicle"].mode()
# Out:
# 0    Automobile
# Name: Type_of_vehicle, dtype: object

# %%
df["Type_of_vehicle"]=df["Type_of_vehicle"].fillna(df["Type_of_vehicle"].mode()[0])

# %%
df["Owner_of_vehicle"].mode()
# Out:
# 0    Owner
# Name: Owner_of_vehicle, dtype: object

# %%
df["Owner_of_vehicle"].unique()
# Out:
# array(['Owner', 'Governmental', nan, 'Organization', 'Other'],
#       dtype=object)

# %%
df["Owner_of_vehicle"]=df["Owner_of_vehicle"].fillna(df["Owner_of_vehicle"].mode()[0])

# %%
df["Service_year_of_vehicle"].mode()
# Out:
# 0    Unknown
# Name: Service_year_of_vehicle, dtype: object

# %%
df["Service_year_of_vehicle"]=df["Service_year_of_vehicle"].fillna(df["Service_year_of_vehicle"].mode()[0])

# %%
df["Defect_of_vehicle"].mode()
# Out:
# 0    No defect
# Name: Defect_of_vehicle, dtype: object

# %%
df["Defect_of_vehicle"].unique()
# Out:
# array(['No defect', nan, '7', '5'], dtype=object)

# %%
# nan means no defect here otherwise it must have been there.  and 5 or 7 classifies the class of defect maybe.

# %%
df["Defect_of_vehicle"]=df["Defect_of_vehicle"].fillna(df["Defect_of_vehicle"].mode()[0])

# %%
df["Area_accident_occured"].mode()
# Out:
# 0    Other
# Name: Area_accident_occured, dtype: object

# %%
df["Area_accident_occured"]=df["Area_accident_occured"].fillna(df["Area_accident_occured"].mode()[0])

# %%
df["Lanes_or_Medians"].mode()
# Out:
# 0    Two-way (divided with broken lines road marking)
# Name: Lanes_or_Medians, dtype: object

# %%
df["Lanes_or_Medians"].unique()
# Out:
# array([nan, 'Undivided Two way', 'other', 'Double carriageway (median)',
#        'One way', 'Two-way (divided with solid lines road marking)',
#        'Two-way (divided with broken lines road marking)', 'Unknown'],
#       dtype=object)

# %%
# we will fill nan with unknown as mode is two way but not every lane or median can be two way.

# %%
df["Lanes_or_Medians"]=df["Lanes_or_Medians"].fillna("Unknown")

# %%
df["Road_allignment"].mode()
# Out:
# 0    Tangent road with flat terrain
# Name: Road_allignment, dtype: object

# %%
df["Road_allignment"].unique()
# Out:
# array(['Tangent road with flat terrain', nan,
#        'Tangent road with mild grade and flat terrain', 'Escarpments',
#        'Tangent road with rolling terrain', 'Gentle horizontal curve',
#        'Tangent road with mountainous terrain and',
#        'Steep grade downward with mountainous terrain',
#        'Sharp reverse curve',
#        'Steep grade upward with mountainous terrain'], dtype=object)

# %%
df["Road_allignment"]=df["Road_allignment"].fillna(df["Road_allignment"].mode()[0])

# %%
df["Types_of_Junction"].mode()
# Out:
# 0    Y Shape
# Name: Types_of_Junction, dtype: object

# %%
df["Types_of_Junction"].unique()
# Out:
# array(['No junction', 'Y Shape', 'Crossing', 'O Shape', 'Other',
#        'Unknown', 'T Shape', 'X Shape', nan], dtype=object)

# %%
# fill it with other 
df["Types_of_Junction"]=df["Types_of_Junction"].fillna("Other")

# %%
df["Road_surface_type"].mode()
# Out:
# 0    Asphalt roads
# Name: Road_surface_type, dtype: object

# %%
df["Road_surface_type"].unique()
# Out:
# array(['Asphalt roads', 'Earth roads', nan,
#        'Asphalt roads with some distress', 'Gravel roads', 'Other'],
#       dtype=object)

# %%
# fill it with other  
df["Road_surface_type"]=df["Road_surface_type"].fillna("Other")

# %%
df["Type_of_collision"].unique()
# Out:
# array(['Collision with roadside-parked vehicles',
#        'Vehicle with vehicle collision',
#        'Collision with roadside objects', 'Collision with animals',
#        'Other', 'Rollover', 'Fall from vehicles',
#        'Collision with pedestrians', 'With Train', 'Unknown', nan],
#       dtype=object)

# %%
# fill it with mode as missing value is less than 5%.
df["Type_of_collision"]=df["Type_of_collision"].fillna(df["Type_of_collision"].mode()[0])

# %%
df["Vehicle_movement"].mode()
# Out:
# 0    Going straight
# Name: Vehicle_movement, dtype: object

# %%
df["Vehicle_movement"].unique()
# Out:
# array(['Going straight', 'U-Turn', 'Moving Backward', 'Turnover',
#        'Waiting to go', 'Getting off', 'Reversing', 'Unknown', 'Parked',
#        'Stopping', 'Overtaking', 'Other', 'Entering a junction', nan],
#       dtype=object)

# %%
# fill it with mode as missing value is less than 5%.
df["Vehicle_movement"]=df["Vehicle_movement"].fillna(df["Vehicle_movement"].mode()[0])

# %%
df["Work_of_casuality"].mode()
# Out:
# 0    Driver
# Name: Work_of_casuality, dtype: object

# %%
df["Work_of_casuality"].unique()
# Out:
# array([nan, 'Driver', 'Other', 'Unemployed', 'Employee', 'Self-employed',
#        'Student', 'Unknown'], dtype=object)

# %%
# fill it with mode as missing value is less than 5%.
df["Work_of_casuality"]=df["Work_of_casuality"].fillna("Other")

# %%
df["Fitness_of_casuality"].mode()
# Out:
# 0    Normal
# Name: Fitness_of_casuality, dtype: object

# %%
df["Fitness_of_casuality"].unique()
# Out:
# array([nan, 'Normal', 'Deaf', 'Other', 'Blind', 'NormalNormal'],
#       dtype=object)

# %%
# fill it with mode as missing value is less
df["Fitness_of_casuality"]=df["Fitness_of_casuality"].fillna(df["Fitness_of_casuality"].mode()[0])

# %%
# we see that there is anomaly as normalnormal can be treated as normal so correcting it.
df["Fitness_of_casuality"]=df["Fitness_of_casuality"].str.replace('NormalNormal','Normal')

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# Fitness_of_casuality           0
# ...

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#FAFAD2;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
# ​
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
#    Feature Engineering
#     </p>
#     </div>

# %%
from datetime import datetime as dt
df["Time"]=pd.to_datetime(df['Time'])

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
#  Extracting new columns:
#     </p>
#     </div>

# %%
df['hour'] = df['Time'].dt.hour
df['minute'] = df['Time'].dt.minute
df["year"]=df["Time"].dt.year
df["day"]=df["Time"].dt.day
df["month"]=df["Time"].dt.month

# %%
df.sample(1)
# Out:
#                      Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 10474 2023-11-17 10:35:00   Wednesday           Under 18          Male
#
#       Vehicle_driver_relation Driving_experience Type_of_vehicle  \
# 10474                   Owner         Above 10yr      Automobile
#
#       Owner_of_vehicle Service_year_of_vehicle Defect_of_vehicle  \
# 10474            Owner                  2-5yrs         No defect
#
#       Area_accident_occured   Lanes_or_Medians  \
# 10474                 Other  Undivided Two way
#
#                       Road_allignment Types_of_Junction Road_surface_type  \
# 10474  Tangent road with flat terrain       No junction     Asphalt roads
#
#       Road_surface_conditions Light_conditions Weather_conditions  \
# 10474             Wet or damp         Daylight             Normal
#
#                     Type_of_collision  Number_of_vehicles_involved  \
# 10474  Vehicle with vehicle collision                            2
#
# ...

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
#   Encoding some columns:
#     </p>
#     </div>

# %%
df["Age_band_of_driver"].unique()
# Out:
# array(['18-30', '31-50', 'Under 18', 'Over 51', 'Unknown'], dtype=object)

# %%
df["Age_band_of_driver"]=df["Age_band_of_driver"].map({'18-30':2,"31-50":3,"Under 18":1,"Over 51":4,"Unknown":0})
# 18-30 =2
# under 18 = 1
# 31-50= 3
# above 51 = 4
# unknown =0

# %%
df["Age_band_of_casualty"].unique()
# age band cant be 5 there is some inconsistency in data. let 5 be 5 as there is a large data having 5 as age band and no driver can be of 5 years , pedestrian can be.
# Out:
# array(['na', '31-50', '18-30', 'Under 18', 'Over 51', '5'], dtype=object)

# %%
df["Age_band_of_casualty"]=df["Age_band_of_casualty"].map({'18-30':2,"31-50":3,"Under 18":1,"Over 51":4,"na":0,"5":5})
# 18-30 =2
# under 18 = 1
# 31-50= 3
# above 51 = 4
# na =0

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#FAFAD2;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
#    INSIGHTS
#     </p>
#     </div>

# %%
df.sample(5)
# Out:
#                      Time Day_of_week  Age_band_of_driver Sex_of_driver  \
# 399   2023-11-17 14:00:00    Saturday                   3          Male
# 6155  2023-11-17 19:32:00   Wednesday                   2          Male
# 34    2023-11-17 13:57:00    Saturday                   4          Male
# 8425  2023-11-17 05:35:00      Friday                   3          Male
# 11746 2023-11-17 14:57:00      Friday                   3          Male
#
#       Vehicle_driver_relation Driving_experience Type_of_vehicle  \
# 399                  Employee              1-2yr      Automobile
# 6155                 Employee         Above 10yr           Other
# 34                   Employee          Below 1yr      Automobile
# 8425                 Employee         Above 10yr           Other
# 11746                   Owner         Above 10yr      Automobile
#
#       Owner_of_vehicle Service_year_of_vehicle Defect_of_vehicle  \
# 399              Owner                  2-5yrs         No defect
# ...

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Age Based Insight:
#     </p>
#     </div>

# %%
df["Age_band_of_driver"].value_counts()
# Out:
# Age_band_of_driver
# 2    4271
# 3    4087
# 4    1585
# 0    1548
# 1     825
# Name: count, dtype: int64

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
#  Highest No. of Accidents done by which age group?
#     </p>
#     </div>

# %%
sns.countplot(x="Age_band_of_driver",data=df,palette="rocket");

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    -People between 18-31 age group has done most no. of accidents.

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
#  Highest No. of Casualties in which age group?
#     </p>
#     </div>

# %%
sns.countplot(x="Age_band_of_casualty",data=df,palette="rocket");

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - A large no. of accidents do not have adequate information on age of the casualties.

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# sex of driver , Male or female?
#     </p>
#     </div>

# %%
sns.countplot(x="Sex_of_driver",data=df,palette="rocket")
# Out:
# <Axes: xlabel='Sex_of_driver', ylabel='count'>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - mainly drivers were male.

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# year wise accidents
#     </p>
#     </div>

# %%
df["month"].unique()
# we can see that the time column is corrupted as all rows have same date and year.
# Out:
# array([11], dtype=int32)

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
#    On which day accidents occured most?
#     </p>
#     </div>

# %%
sns.countplot(x="Day_of_week",data=df,palette="rocket")
# Out:
# <Axes: xlabel='Day_of_week', ylabel='count'>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - mostly accidents occured on friday.

# %%
df.sample(2)
# Out:
#                     Time Day_of_week  Age_band_of_driver Sex_of_driver  \
# 7113 2023-11-17 07:50:00      Friday                   2          Male
# 5308 2023-11-17 22:15:00   Wednesday                   2          Male
#
#      Vehicle_driver_relation Driving_experience Type_of_vehicle  \
# 7113                Employee              2-5yr            Taxi
# 5308                Employee              1-2yr  Lorry (11?40Q)
#
#      Owner_of_vehicle Service_year_of_vehicle Defect_of_vehicle  \
# 7113            Owner                 Unknown         No defect
# 5308            Owner                  2-5yrs         No defect
#
#      Area_accident_occured             Lanes_or_Medians  \
# 7113          Church areas                      One way
# 5308          Office areas  Double carriageway (median)
#
#                      Road_allignment Types_of_Junction Road_surface_type  \
# 7113  Tangent road with flat terrain           Y Shape     Asphalt roads
# ...

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
#    Age and Sex of Drivers
#     </p>
#     </div>

# %%
df.groupby(["Age_band_of_driver"])["Sex_of_driver"].value_counts()
# Out:
# Age_band_of_driver  Sex_of_driver
# 0                   Male              967
#                     Female            569
#                     Unknown            12
# 1                   Male              807
#                     Unknown            11
#                     Female              7
# 2                   Male             4150
#                     Unknown            66
#                     Female             55
# 3                   Male             3982
#                     Unknown            66
#                     Female             39
# 4                   Male             1531
#                     Female             31
#                     Unknown            23
# Name: count, dtype: int64

# %%
sns.countplot(x="Age_band_of_driver",data=df,hue="Sex_of_driver",palette="rocket")
# Out:
# <Axes: xlabel='Age_band_of_driver', ylabel='count'>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - almost in all age groups mostly drivers were male.

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
#    What was the Driver's relation with vehicle?
#     </p>
#     </div>

# %%
df.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Vehicle_driver_relation', 'Driving_experience', 'Type_of_vehicle',
#        'Owner_of_vehicle', 'Service_year_of_vehicle', 'Defect_of_vehicle',
#        'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment',
#        'Types_of_Junction', 'Road_surface_type', 'Road_surface_conditions',
#        'Light_conditions', 'Weather_conditions', 'Type_of_collision',
#        'Number_of_vehicles_involved', 'Number_of_casualties',
#        'Vehicle_movement', 'Casualty_class', 'Sex_of_casualty',
#        'Age_band_of_casualty', 'Casualty_severity', 'Work_of_casuality',
#        'Fitness_of_casuality', 'Pedestrian_movement', 'Cause_of_accident',
#        'Accident_severity', 'hour', 'minute', 'year', 'day', 'month'],
#       dtype='object')

# %%
df["Vehicle_driver_relation"].value_counts()
# Out:
# Vehicle_driver_relation
# Employee    9627
# Owner       1973
# Other        702
# Unknown       14
# Name: count, dtype: int64

# %%
sns.countplot(x="Vehicle_driver_relation",data=df,palette="rocket")
# Out:
# <Axes: xlabel='Vehicle_driver_relation', ylabel='count'>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - large no. of drivers were not real owners of car only a small share were owners rest were employers employeed to drive .

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
#    how many owners were male or female?

# %%
x=df[df["Vehicle_driver_relation"]=="Owner"]

# %%
c=x["Sex_of_driver"].value_counts()
c
# Out:
# Sex_of_driver
# Male       1837
# Female      106
# Unknown      30
# Name: count, dtype: int64

# %%
plt.pie(x=c,data=c,labels=c.index,autopct="%.2f%%",colors=["#DC143C","#E9967A","#FFD700"]);

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - 93% owners were male rest were female.

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
#    Driving Experience of Drivers

# %%
sns.countplot(x="Driving_experience",data=df,palette="rocket")
# Out:
# <Axes: xlabel='Driving_experience', ylabel='count'>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - large no. of drivers have 5-10 years of experience.

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
#    Most used type of Vehicles

# %%
sns.countplot(x="Type_of_vehicle",data=df,palette="rocket")
plt.xticks(rotation=90);

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - mostly used vehicle were autombiles, lorrry(41?100q)
#    - least used were bicycles, bajaj,turbo,ridden horses

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
#    Who owned the vehicle?

# %%
x=df["Owner_of_vehicle"].value_counts().to_frame()
x
# Out:
#                   count
# Owner_of_vehicle
# Owner             10941
# Governmental       1041
# Organization        312
# Other                22

# %%
plt.pie(x="count",data=x,labels=x.index,explode=[1,0,1,2],autopct="%.2f%%",colors=["#DC143C","#E9967A","#FFD700","#FAEBD7"]);

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - mostly vehicles were privately owned and others were governmental or organisational.

# %%
df.head(2)
# Out:
#                  Time Day_of_week  Age_band_of_driver Sex_of_driver  \
# 0 2023-11-17 17:02:00      Monday                   2          Male
# 1 2023-11-17 17:02:00      Monday                   3          Male
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
#
#   Owner_of_vehicle Service_year_of_vehicle Defect_of_vehicle  \
# 0            Owner              Above 10yr         No defect
# 1            Owner                 5-10yrs         No defect
#
#   Area_accident_occured   Lanes_or_Medians                 Road_allignment  \
# 0     Residential areas            Unknown  Tangent road with flat terrain
# 1          Office areas  Undivided Two way  Tangent road with flat terrain
#
#   Types_of_Junction Road_surface_type Road_surface_conditions  \
# 0       No junction     Asphalt roads                     Dry
# ...

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
#  Age of vehicle?

# %%
plt.hist(df["Service_year_of_vehicle"],bins=5,color="#FFD700",edgecolor="#E9967A");

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - age of mostly vehicles were unknown rest were around 2-5 years or above 5 or 10 years.

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
#  how many vehicles were defected ?
#
#   ( no defect
#    5: less defect
#    7: severly defect)

# %%
x=df["Defect_of_vehicle"].value_counts()
c=x.to_frame()
c
# Out:
#                    count
# Defect_of_vehicle
# No defect          12204
# 7                     76
# 5                     36

# %%
plt.pie(x="count",data=c,labels=c.index,explode=[1,0,1,],autopct="%.2f%%",colors=["#DC143C","#E9967A","#FFD700","#FAEBD7"]);

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - no defect in mostly vehicles

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
#  Which areas are more prone to accident?

# %%
df.head(2)
# Out:
#                  Time Day_of_week  Age_band_of_driver Sex_of_driver  \
# 0 2023-11-17 17:02:00      Monday                   2          Male
# 1 2023-11-17 17:02:00      Monday                   3          Male
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
#
#   Owner_of_vehicle Service_year_of_vehicle Defect_of_vehicle  \
# 0            Owner              Above 10yr         No defect
# 1            Owner                 5-10yrs         No defect
#
#   Area_accident_occured   Lanes_or_Medians                 Road_allignment  \
# 0     Residential areas            Unknown  Tangent road with flat terrain
# 1          Office areas  Undivided Two way  Tangent road with flat terrain
#
#   Types_of_Junction Road_surface_type Road_surface_conditions  \
# 0       No junction     Asphalt roads                     Dry
# ...

# %%
sns.countplot(x="Area_accident_occured",data=df,palette="rocket");
plt.xticks(rotation=90);

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - office areas and other areas not prescricbed above were most prone to accident
#    - recreation areas ,rural areas were least prone to accidents.

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
#  Conditions of area which was more prone to accident?

# %%
a=df[df["Area_accident_occured"]==("Office areas")]  
b=df[df["Area_accident_occured"]==("Other")] 
ac=pd.concat([a,b])

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#FF69B4;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
#  here , i checked whether certain conditions like lanes medians, road type, road condition, light and weather etc leads to accidents or not in accident prone areas.

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,7,1)
sns.countplot(x="Lanes_or_Medians",data=ac,palette="rocket")
plt.xticks(rotation=90);
plt.title("Lanes or Median")
plt.subplot(1,7,2)
sns.countplot(x="Road_allignment",data=ac,palette="rocket")
plt.xticks(rotation=90);
plt.title("road allignment")
plt.subplot(1,7,3)
sns.countplot(x="Types_of_Junction",data=ac,palette="rocket")
plt.xticks(rotation=90);
plt.title("types of junction")
plt.subplot(1,7,4)
sns.countplot(x="Road_surface_type",data=ac,palette="rocket")
plt.xticks(rotation=90);
plt.title("road surface type")
plt.subplot(1,7,5)
sns.countplot(x="Road_surface_conditions",data=ac,palette="rocket")
plt.xticks(rotation=90);
plt.title("road surface condition")
plt.subplot(1,7,6)
sns.countplot(x="Light_conditions",data=ac,palette="rocket")
plt.xticks(rotation=90);
plt.title("Light condition")
plt.subplot(1,7,7)
sns.countplot(x="Weather_conditions",data=ac,palette="rocket")
plt.xticks(rotation=90);
plt.title("weather conditions")
# Out:
# Text(0.5, 1.0, 'weather conditions')

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - reasons for most no. of accidents were:
#     - two way lane( divided by broken line road markings)
#     - tangent road with flat terrain.
#     - Y-junction
#     - asphalt roads
#     - dry road surface
#     - mainly accidents occur in daylight.
#     - normal weather

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
#  How collision happened?

# %%
sns.countplot(x="Type_of_collision",data=df,palette="rocket")
plt.xticks(rotation=90);

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    -  most no. of accidents happened by vehicle to vehicle collision:

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
#  How many vehicles were involved in these accidents?

# %%
df["Number_of_vehicles_involved"].value_counts()
# Out:
# Number_of_vehicles_involved
# 2    8340
# 1    1996
# 3    1568
# 4     363
# 6      42
# 7       7
# Name: count, dtype: int64

# %%
plt.hist(x="Number_of_vehicles_involved",data=df,color="#D8BFD8",edgecolor="#FF0000");

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    -  most no. of accidents happened between 2 vehciles and in some cases even 6 or 7 vehicles were involved.

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
#  How many casualties happened?

# %%
sns.countplot(x='Number_of_casualties',data=df,palette="rocket")
# Out:
# <Axes: xlabel='Number_of_casualties', ylabel='count'>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - In most no. of accidents only 1 Casualty happened

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
#  Does Movement of vehicle has any relation with type of collision?

# %%
df.groupby(['Type_of_collision'])['Vehicle_movement'].value_counts()
# Out:
# Type_of_collision                        Vehicle_movement
# Collision with animals                   Going straight          123
#                                          Moving Backward          13
#                                          Other                    10
#                                          Turnover                  7
#                                          Reversing                 6
#                                          Overtaking                4
#                                          Getting off               4
#                                          U-Turn                    2
#                                          Unknown                   1
#                                          Waiting to go             1
# Collision with pedestrians               Going straight          605
#                                          Moving Backward          78
#                                          Other                    67
# ...

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - Vehicle movement doesnt matter as collision happened in all cases

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
#  Who was Affected more ?

# %%
sns.countplot(x="Casualty_class",data=df,palette="rocket",hue="Sex_of_casualty")
# Out:
# <Axes: xlabel='Casualty_class', ylabel='count'>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - In most cases drivers or riders were affected and their gender was male.

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
#  which age group was more and least affected?

# %%
sns.countplot(x="Age_band_of_casualty",data=df,palette="rocket")
# Out:
# <Axes: xlabel='Age_band_of_casualty', ylabel='count'>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - In most cases age of casualty was unknown.

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
#  what was the occupation and fitness of casualty?

# %%
sns.countplot(x="Work_of_casuality",data=df,hue="Fitness_of_casuality",palette="rocket")
plt.xticks(rotation=90);

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - In most cases Casaulty occupation was driver
#    and most of casualties were normal.

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
# what was accident severity?

# %%
sns.countplot(x='Accident_severity',data=df,palette="rocket")
# Out:
# <Axes: xlabel='Accident_severity', ylabel='count'>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - in  Most  accidents there was only slight injury.

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
# Was there any pedestrian movement which resulted into accident ?

# %%
sns.countplot(x='Pedestrian_movement',data=df,palette="rocket")
plt.xticks(rotation=90);

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - in  Most Cases no pedestrian was involved.

# %%
df.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Vehicle_driver_relation', 'Driving_experience', 'Type_of_vehicle',
#        'Owner_of_vehicle', 'Service_year_of_vehicle', 'Defect_of_vehicle',
#        'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment',
#        'Types_of_Junction', 'Road_surface_type', 'Road_surface_conditions',
#        'Light_conditions', 'Weather_conditions', 'Type_of_collision',
#        'Number_of_vehicles_involved', 'Number_of_casualties',
#        'Vehicle_movement', 'Casualty_class', 'Sex_of_casualty',
#        'Age_band_of_casualty', 'Casualty_severity', 'Work_of_casuality',
#        'Fitness_of_casuality', 'Pedestrian_movement', 'Cause_of_accident',
#        'Accident_severity', 'hour', 'minute', 'year', 'day', 'month'],
#       dtype='object')

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#DB7093;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;"
#
# What was cause of accident?

# %%
sns.countplot(x="Cause_of_accident",data=df,palette="rocket")
plt.xticks(rotation=90);

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:3px;
#            background-color: #FAEBD7;
#            font-size:100%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:#D2691E;
#          border-style: solid;
#         border-width: 7px;
#         font-size:120%;
#           text-align:left;"
#
#  **OBSERVATION:**
#    - Main causes of accidents were :
#     - no distancing
#     - changing lane to the right
#     - changing lane to the left
#     - driving carelessly

# %% [markdown]
# <div style="color:BLACK;
#            display:fill;
#            border-radius:2px;
#            background-color:#FF7F50;
#            font-size:140%;
#            font-family:Georgia;
#            letter-spacing:0.5px">
#
# <p style="padding: 5px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
#    CONCLUSION:
#     <ul>
#         <li> Importing Numpy for Mathematical Operations on Arrays and Dataframe.</li>
#         <li> Importing Pandas for Reading Data and Data Manipulation.</li>
#          <li> Importing Matplotlib & Seaborn to show insights and visualisation from the dataset.</li>
#           <li> Importing Warnings for Warnings Messages that are typically issued in dataframe where it is used to show warning messages.</li>
#
# </p>
# </div>
